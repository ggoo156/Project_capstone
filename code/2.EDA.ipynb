# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Import data

# %%
df_res_ins = pd.read_csv('../dataset/restaurant_inspection_result_cleaned', index_col=0)
df_yelp = pd.read_csv('../dataset/yelp_nyc', index_col=0)

# %% [markdown]
# ### Clean data

# %% [markdown]
# #### Inspection data

# %%
# Drop null values in building columns
df_res_ins.dropna(subset=['building'], inplace=True)

# Combine building and street columns to get the address
df_res_ins['address'] = df_res_ins.apply(lambda row: str(row.building) + str(" ") + str(row.street), axis=1)

# Change dba to name to match yelp data
df_res_ins.rename(columns={'dba': 'name'}, inplace=True)

# Make address all lower-case.
df_res_ins["address"] = [i.lower() for i in df_res_ins["address"]]

# Make phone all string
df_res_ins["phone"] = [str(i) for i in df_res_ins["phone"]]

# %% [markdown]
# #### yelp data

# %%
# Drop null values in address column
df_yelp.dropna(subset=['address'], inplace=True)

# Fill 0 in null value in phone column
df_yelp['phone'].fillna(0000000000, inplace=True)

# Make the name of the restaurant all lower-case.
df_yelp['name'] = [i.lower() for i in df_yelp["name"]]

# Make address all lower-case.
df_yelp['address'] = [str(i).lower() for i in df_yelp["address"]]

# Make phone all string
df_yelp['phone'] = [str(int(i))[1:11] for i in df_yelp["phone"]]

# %% [markdown]
# ### Unify `address`  and `name` values in both dataset

# %%
# Apply the following translation to both of inspection data and yelp data.
# For address,

address_replace_dict = {' avenue': ' ave',
                        ' street': ' st',
                        ' west ': ' w ',
                        " east ": " e ",
                        "th ave": " ave",
                        "th st": " st",
                        "road": 'rd',
                        "lane": "ln",
                        "floor": 'fl',
                        'place': 'pl',
                        "1st": "1",
                        "2nd": "2",
                        "3rd": '3',
                        "-": "",
                        ".": ""}

for key in address_replace_dict:
    df_res_ins['address'] = [i.replace(key, address_replace_dict[key]) for i in df_res_ins['address']]
    df_yelp['address'] = [i.replace(key, address_replace_dict[key]) for i in df_yelp['address']]

# %%
# For restaurant name,

name_replace_dict = {"&": "and",
                    "new york": "ny",
                    " ice cream": "",
                    " chinese restarurant": "",
                    " sushi": ""} 

for key in name_replace_dict:
    df_res_ins['name'] = [i.replace(key, name_replace_dict[key]) for i in df_res_ins['name']]
    df_yelp['name'] = [i.replace(key, name_replace_dict[key]) for i in df_yelp['name']]

# %% [markdown]
# ### Combine inspection data and yelp data by address, name and phone number

# %%
df_combined = df_res_ins.merge(df_yelp, how='inner', left_on=['address','name', 'phone', 'zipcode'], right_on=['address','name','phone', 'zip_code'])
df_combined
# Out:
#          camis                              name           boro building  \
# 0     30075445             morris park bake shop          bronx     1007
# 1     30075445             morris park bake shop          bronx     1007
# 2     30075445             morris park bake shop          bronx     1007
# 3     40360076                            carvel       brooklyn      203
# 4     40360076                            carvel       brooklyn      203
# 5     40360076                            carvel       brooklyn      203
# 6     40361618                        sal's deli         queens    12908
# 7     40361618                        sal's deli         queens    12908
# 8     40361618                        sal's deli         queens    12908
# 9     40361618                        sal's deli         queens    12908
# 10    40361618                        sal's deli         queens    12908
# 11    40361618                        sal's deli         queens    12908
# 12    40361618                        sal's deli         queens    12908
# 13    40361618                        sal's deli         queens    12908
# 14    40362715                  the country cafe      manhattan       60
# 15    40362715                  the country cafe      manhattan       60
# 16    40362715                  the country cafe      manhattan       60
# 17    40362715                  the country cafe      manhattan       60
# 18    40362715                  the country cafe      manhattan       60
# 19    40362715                  the country cafe      manhattan       60
# 20    40362715                  the country cafe      manhattan       60
# 21    40362715                  the country cafe      manhattan       60
# 22    40362715                  the country cafe      manhattan       60
# 23    40362715                  the country cafe      manhattan       60
# 24    40362715                  the country cafe      manhattan       60
# 25    40363098                    dunkin' donuts       brooklyn       56
# 26    40363098                    dunkin' donuts       brooklyn       56
# 27    40363098                    dunkin' donuts       brooklyn       56
# 28    40363098                    dunkin' donuts       brooklyn       56
# 29    40363098                    dunkin' donuts       brooklyn       56
# ...        ...                               ...            ...      ...
# 7677  50083799                      fuji hibachi      manhattan      321
# 7678  50083799                      fuji hibachi      manhattan      321
# 7679  50083936                           rockbar      manhattan      185
# 7680  50084346                              glou       brooklyn      406
# 7681  50084346                              glou       brooklyn      406
# 7682  50084363                              hiro      manhattan      160
# 7683  50084363                              hiro      manhattan      160
# 7684  50084404                   buccaneer diner         queens     9301
# 7685  50084746         williamsburg thai cuisine       brooklyn      212
# 7686  50084746         williamsburg thai cuisine       brooklyn      212
# 7687  50084763  flaming grill and supreme buffet  staten island     1501
# 7688  50084763  flaming grill and supreme buffet  staten island     1501
# 7689  50084763  flaming grill and supreme buffet  staten island     1501
# 7690  50084763  flaming grill and supreme buffet  staten island     1501
# 7691  50084878                        hunan west       brooklyn     6165
# 7692  50084878                        hunan west       brooklyn     6165
# 7693  50084903              dumplings and things         queens     4526
# 7694  50084903              dumplings and things         queens     4526
# 7695  50085247                 thai farm kitchen       brooklyn      416
# 7696  50085247                 thai farm kitchen       brooklyn      416
# 7697  50085630                           kumo ii       brooklyn      512
# 7698  50085630                           kumo ii       brooklyn      512
# 7699  50085884             kennedy fried chicken          bronx      730
# 7700  50085949         aunt butchies of brooklyn  staten island     4864
# 7701  50086222                  one stop express       brooklyn     8621
# 7702  50086222                  one stop express       brooklyn     8621
# 7703  50086524                  stop and go deli          bronx      134
# 7704  50086524                  stop and go deli          bronx      134
# 7705  50087348                               umi         queens    17713
# 7706  50087437             ny thai grill and bar      manhattan      137
#
#                street  zipcode       phone  \
# 0     morris park ave    10462  7188924968
# 1     morris park ave    10462  7188924968
# 2     morris park ave    10462  7188924968
# 3       church avenue    11218  7184389501
# 4       church avenue    11218  7184389501
# 5       church avenue    11218  7184389501
# 6           20 avenue    11356  7186619498
# 7           20 avenue    11356  7186619498
# 8           20 avenue    11356  7186619498
# 9           20 avenue    11356  7186619498
# 10          20 avenue    11356  7186619498
# 11          20 avenue    11356  7186619498
# 12          20 avenue    11356  7186619498
# 13          20 avenue    11356  7186619498
# 14        wall street    10005  3474279132
# 15        wall street    10005  3474279132
# 16        wall street    10005  3474279132
# 17        wall street    10005  3474279132
# 18        wall street    10005  3474279132
# 19        wall street    10005  3474279132
# 20        wall street    10005  3474279132
# 21        wall street    10005  3474279132
# 22        wall street    10005  3474279132
# 23        wall street    10005  3474279132
# 24        wall street    10005  3474279132
# 25       court street    11201  7186252068
# 26       court street    11201  7186252068
# 27       court street    11201  7186252068
# 28       court street    11201  7186252068
# 29       court street    11201  7186252068
# ...               ...      ...         ...
# 7677        w 42nd st    10036  2127571820
# 7678        w 42nd st    10036  2127571820
# 7679   christopher st    10014  2126751864
# 7680       rogers ave    11225  7184839211
# 7681       rogers ave    11225  7184839211
# 7682       freedom pl    10069  2128737900
# 7683       freedom pl    10069  2128737900
# 7684     astoria blvd    11369  7184295188
# 7685      bedford ave    11249  9293377651
# 7686      bedford ave    11249  9293377651
# 7687       forest ave    10302  7184476888
# 7688       forest ave    10302  7184476888
# 7689       forest ave    10302  7184476888
# 7690       forest ave    10302  7184476888
# 7691   strickland ave    11234  7184441678
# 7692   strickland ave    11234  7184441678
# 7693          46th st    11104  7183922337
# 7694          46th st    11104  7183922337
# 7695       church ave    11218  3475339368
# 7696       church ave    11218  3475339368
# 7697         court st    11231  7182225758
# 7698         court st    11231  7182225758
# 7699       e 149th st    10455  7186653831
# 7700   arthur kill rd    10309  7182270002
# 7701          4th ave    11209  7182383888
# 7702          4th ave    11209  7182383888
# 7703   westchester sq    10461  7187920683
# 7704   westchester sq    10461  7187920683
# 7705       union tpke    11366  7189695668
# 7706        e 45th st    10017  2125818808
#
#                                     cuisine_description inspection_date  \
# 0                                                Bakery      2016-02-18
# 1                                                Bakery      2017-05-18
# 2                                                Bakery      2018-05-11
# 3                       Ice Cream, Gelato, Yogurt, Ices      2016-02-09
# 4                       Ice Cream, Gelato, Yogurt, Ices      2017-03-16
# 5                       Ice Cream, Gelato, Yogurt, Ices      2018-03-20
# 6                                          Delicatessen      2015-07-23
# 7                                          Delicatessen      2015-08-12
# 8                                          Delicatessen      2016-01-28
# 9                                          Delicatessen      2016-02-11
# 10                                         Delicatessen      2016-09-13
# 11                                         Delicatessen      2017-12-01
# 12                                         Delicatessen      2018-01-24
# 13                                         Delicatessen      2018-06-05
# 14                       Sandwiches/Salads/Mixed Buffet      2016-03-11
# 15                       Sandwiches/Salads/Mixed Buffet      2016-04-25
# 16                       Sandwiches/Salads/Mixed Buffet      2016-09-06
# 17                       Sandwiches/Salads/Mixed Buffet      2016-10-07
# 18                       Sandwiches/Salads/Mixed Buffet      2017-03-24
# 19                       Sandwiches/Salads/Mixed Buffet      2018-04-13
# 20                       Sandwiches/Salads/Mixed Buffet      2018-05-25
# 21                       Sandwiches/Salads/Mixed Buffet      2018-10-17
# 22                       Sandwiches/Salads/Mixed Buffet      2018-10-24
# 23                       Sandwiches/Salads/Mixed Buffet      2018-10-30
# 24                       Sandwiches/Salads/Mixed Buffet      2019-01-04
# 25                                               Donuts      2015-12-14
# 26                                               Donuts      2015-12-14
# 27                                               Donuts      2015-12-14
# 28                                               Donuts      2015-12-14
# 29                                               Donuts      2017-01-12
# ...                                                 ...             ...
# 7677                                           Japanese      2018-11-01
# 7678                                           Japanese      2018-12-26
# 7679  Bottled beverages, including water, sodas, jui...      2018-10-29
# 7680                                              Tapas      2019-01-11
# 7681                                              Tapas      2019-01-30
# 7682                                            Chinese      2018-11-01
# 7683                                            Chinese      2018-12-28
# 7684                                           American      2018-11-05
# 7685                                               Thai      2018-10-25
# 7686                                               Thai      2018-11-07
# 7687                                            Chinese      2018-12-06
# 7688                                            Chinese      2018-12-27
# 7689                                            Chinese      2019-01-16
# 7690                                            Chinese      2019-01-24
# 7691                                            Chinese      2018-11-29
# 7692                                            Chinese      2019-01-03
# 7693                                            Chinese      2018-12-05
# 7694                                            Chinese      2018-12-24
# 7695                                               Thai      2018-11-28
# 7696                                               Thai      2018-12-13
# 7697                                           Japanese      2018-12-13
# 7698                                           Japanese      2019-01-16
# 7699                                           American      2018-12-21
# 7700                                            Italian      2019-01-16
# 7701                                            Chinese      2018-12-19
# 7702                                            Chinese      2019-01-07
# 7703                                       Delicatessen      2019-01-10
# 7704                                       Delicatessen      2019-01-25
# 7705                                           Japanese      2019-01-10
# 7706                                               Thai      2019-01-16
#
#                                                  action violation_code  \
# 0       Violations were cited in the following area(s).            04L
# 1       Violations were cited in the following area(s).            06D
# 2       Violations were cited in the following area(s).            08C
# 3       Violations were cited in the following area(s).            06C
# 4       Violations were cited in the following area(s).            10B
# 5       Violations were cited in the following area(s).            04K
# 6       Violations were cited in the following area(s).            02G
# 7       Violations were cited in the following area(s).            10F
# 8       Violations were cited in the following area(s).            02B
# 9       Violations were cited in the following area(s).            06C
# 10      Violations were cited in the following area(s).            06D
# 11      Violations were cited in the following area(s).            02B
# 12      Violations were cited in the following area(s).            04L
# 13      Violations were cited in the following area(s).            06C
# 14      Violations were cited in the following area(s).            02G
# 15      Violations were cited in the following area(s).            02G
# 16      Violations were cited in the following area(s).            02G
# 17      Violations were cited in the following area(s).            04M
# 18      Violations were cited in the following area(s).            06E
# 19      Violations were cited in the following area(s).            02B
# 20      Violations were cited in the following area(s).            06E
# 21    Establishment Closed by DOHMH.  Violations wer...            04H
# 22                     Establishment re-closed by DOHMH            04M
# 23                     Establishment re-opened by DOHMH            10B
# 24      Violations were cited in the following area(s).            06C
# 25      Violations were cited in the following area(s).            06C
# 26      Violations were cited in the following area(s).            06C
# 27      Violations were cited in the following area(s).            06C
# 28      Violations were cited in the following area(s).            06C
# 29      Violations were cited in the following area(s).            04L
# ...                                                 ...            ...
# 7677    Violations were cited in the following area(s).            02G
# 7678    Violations were cited in the following area(s).            02B
# 7679    Violations were cited in the following area(s).            04H
# 7680    Violations were cited in the following area(s).            06G
# 7681    Violations were cited in the following area(s).            02G
# 7682    Violations were cited in the following area(s).            04H
# 7683    Violations were cited in the following area(s).            06D
# 7684    Violations were cited in the following area(s).            06C
# 7685    Violations were cited in the following area(s).            02B
# 7686    Violations were cited in the following area(s).            04N
# 7687    Violations were cited in the following area(s).            02G
# 7688    Violations were cited in the following area(s).            02B
# 7689  Establishment Closed by DOHMH.  Violations wer...            02B
# 7690                   Establishment re-opened by DOHMH            06D
# 7691    Violations were cited in the following area(s).            04L
# 7692    Violations were cited in the following area(s).            02G
# 7693    Violations were cited in the following area(s).            02H
# 7694    Violations were cited in the following area(s).            06C
# 7695    Violations were cited in the following area(s).            04L
# 7696    Violations were cited in the following area(s).            06C
# 7697    Violations were cited in the following area(s).            06E
# 7698    Violations were cited in the following area(s).            06C
# 7699    Violations were cited in the following area(s).            04L
# 7700    Violations were cited in the following area(s).            06C
# 7701    Violations were cited in the following area(s).            02B
# 7702    Violations were cited in the following area(s).            02B
# 7703    Violations were cited in the following area(s).            02G
# 7704    Violations were cited in the following area(s).            02G
# 7705    Violations were cited in the following area(s).            10F
# 7706    Violations were cited in the following area(s).            04L
#
#                                   violation_description critical_flag  score  \
# 0     Evidence of mice or live mice present in facil...      Critical   10.0
# 1     Food contact surface not properly washed, rins...      Critical    7.0
# 2     Pesticide use not in accordance with label or ...  Not Critical    5.0
# 3     Food not protected from potential source of co...      Critical    5.0
# 4     Plumbing not properly installed or maintained;...  Not Critical    6.0
# 5     Evidence of rats or live rats present in facil...      Critical   13.0
# 6     Cold food item held above 41Âº F (smoked fish ...      Critical   21.0
# 7     Non-food contact surface improperly constructe...  Not Critical    6.0
# 8           Hot food item not held at or above 140Âº F.      Critical   18.0
# 9     Food not protected from potential source of co...      Critical    7.0
# 10    Food contact surface not properly washed, rins...      Critical    8.0
# 11          Hot food item not held at or above 140Âº F.      Critical   24.0
# 12    Evidence of mice or live mice present in facil...      Critical   13.0
# 13    Food not protected from potential source of co...      Critical   11.0
# 14    Cold food item held above 41Âº F (smoked fish ...      Critical   14.0
# 15    Cold food item held above 41Âº F (smoked fish ...      Critical   51.0
# 16    Cold food item held above 41Âº F (smoked fish ...      Critical   33.0
# 17    Live roaches present in facility's food and/or...      Critical   24.0
# 18    Sanitized equipment or utensil, including in-u...      Critical   10.0
# 19          Hot food item not held at or above 140Âº F.      Critical   27.0
# 20    Sanitized equipment or utensil, including in-u...      Critical    5.0
# 21    Raw, cooked or prepared food is adulterated, c...      Critical   46.0
# 22    Live roaches present in facility's food and/or...      Critical   11.0
# 23    Plumbing not properly installed or maintained;...  Not Critical    4.0
# 24    Food not protected from potential source of co...      Critical   12.0
# 25    Food not protected from potential source of co...      Critical    7.0
# 26    Food not protected from potential source of co...      Critical    7.0
# 27    Food not protected from potential source of co...      Critical    7.0
# 28    Food not protected from potential source of co...      Critical    7.0
# 29    Evidence of mice or live mice present in facil...      Critical   12.0
# ...                                                 ...           ...    ...
# 7677  Cold food item held above 41Âº F (smoked fish ...      Critical   24.0
# 7678        Hot food item not held at or above 140Âº F.      Critical   36.0
# 7679  Raw, cooked or prepared food is adulterated, c...      Critical   12.0
# 7680  HACCP plan not approved or approved HACCP plan...      Critical   28.0
# 7681  Cold food item held above 41Âº F (smoked fish ...      Critical    9.0
# 7682  Raw, cooked or prepared food is adulterated, c...      Critical   13.0
# 7683  Food contact surface not properly washed, rins...      Critical    9.0
# 7684  Food not protected from potential source of co...      Critical   12.0
# 7685        Hot food item not held at or above 140Âº F.      Critical    7.0
# 7686  Filth flies or food/refuse/sewage-associated (...      Critical   13.0
# 7687  Cold food item held above 41Âº F (smoked fish ...      Critical   50.0
# 7688        Hot food item not held at or above 140Âº F.      Critical   50.0
# 7689        Hot food item not held at or above 140Âº F.      Critical   42.0
# 7690  Food contact surface not properly washed, rins...      Critical    5.0
# 7691  Evidence of mice or live mice present in facil...      Critical   16.0
# 7692  Cold food item held above 41Âº F (smoked fish ...      Critical   13.0
# 7693  Food not cooled by an approved method whereby ...      Critical   47.0
# 7694  Food not protected from potential source of co...      Critical    8.0
# 7695  Evidence of mice or live mice present in facil...      Critical   53.0
# 7696  Food not protected from potential source of co...      Critical   11.0
# 7697  Sanitized equipment or utensil, including in-u...      Critical   14.0
# 7698  Food not protected from potential source of co...      Critical   11.0
# 7699  Evidence of mice or live mice present in facil...      Critical   13.0
# 7700  Food not protected from potential source of co...      Critical   10.0
# 7701        Hot food item not held at or above 140Âº F.      Critical   17.0
# 7702        Hot food item not held at or above 140Âº F.      Critical    7.0
# 7703  Cold food item held above 41Âº F (smoked fish ...      Critical   37.0
# 7704  Cold food item held above 41Âº F (smoked fish ...      Critical   13.0
# 7705  Non-food contact surface improperly constructe...  Not Critical    2.0
# 7706  Evidence of mice or live mice present in facil...      Critical   21.0
#
#                                        inspection_type               address  \
# 0                Cycle Inspection / Initial Inspection  1007 morris park ave
# 1                Cycle Inspection / Initial Inspection  1007 morris park ave
# 2                Cycle Inspection / Initial Inspection  1007 morris park ave
# 3                Cycle Inspection / Initial Inspection        203 church ave
# 4                Cycle Inspection / Initial Inspection        203 church ave
# 5                Cycle Inspection / Initial Inspection        203 church ave
# 6                Cycle Inspection / Initial Inspection          12908 20 ave
# 7                     Cycle Inspection / Re-inspection          12908 20 ave
# 8                Cycle Inspection / Initial Inspection          12908 20 ave
# 9                     Cycle Inspection / Re-inspection          12908 20 ave
# 10               Cycle Inspection / Initial Inspection          12908 20 ave
# 11               Cycle Inspection / Initial Inspection          12908 20 ave
# 12                    Cycle Inspection / Re-inspection          12908 20 ave
# 13               Cycle Inspection / Initial Inspection          12908 20 ave
# 14               Cycle Inspection / Initial Inspection            60 wall st
# 15                    Cycle Inspection / Re-inspection            60 wall st
# 16               Cycle Inspection / Initial Inspection            60 wall st
# 17                    Cycle Inspection / Re-inspection            60 wall st
# 18               Cycle Inspection / Initial Inspection            60 wall st
# 19               Cycle Inspection / Initial Inspection            60 wall st
# 20                    Cycle Inspection / Re-inspection            60 wall st
# 21               Cycle Inspection / Initial Inspection            60 wall st
# 22             Cycle Inspection / Reopening Inspection            60 wall st
# 23             Cycle Inspection / Reopening Inspection            60 wall st
# 24                    Cycle Inspection / Re-inspection            60 wall st
# 25               Cycle Inspection / Initial Inspection           56 court st
# 26               Cycle Inspection / Initial Inspection           56 court st
# 27               Cycle Inspection / Initial Inspection           56 court st
# 28               Cycle Inspection / Initial Inspection           56 court st
# 29               Cycle Inspection / Initial Inspection           56 court st
# ...                                                ...                   ...
# 7677     Pre-permit (Operational) / Initial Inspection           321 w 42 st
# 7678          Pre-permit (Operational) / Re-inspection           321 w 42 st
# 7679     Pre-permit (Operational) / Initial Inspection    185 christopher st
# 7680     Pre-permit (Operational) / Initial Inspection        406 rogers ave
# 7681          Pre-permit (Operational) / Re-inspection        406 rogers ave
# 7682     Pre-permit (Operational) / Initial Inspection        160 freedom pl
# 7683          Pre-permit (Operational) / Re-inspection        160 freedom pl
# 7684     Pre-permit (Operational) / Initial Inspection     9301 astoria blvd
# 7685     Pre-permit (Operational) / Initial Inspection       212 bedford ave
# 7686          Pre-permit (Operational) / Re-inspection       212 bedford ave
# 7687     Pre-permit (Operational) / Initial Inspection       1501 forest ave
# 7688          Pre-permit (Operational) / Re-inspection       1501 forest ave
# 7689  Pre-permit (Operational) / Compliance Inspection       1501 forest ave
# 7690   Pre-permit (Operational) / Reopening Inspection       1501 forest ave
# 7691     Pre-permit (Operational) / Initial Inspection   6165 strickland ave
# 7692          Pre-permit (Operational) / Re-inspection   6165 strickland ave
# 7693     Pre-permit (Operational) / Initial Inspection            4526 46 st
# 7694          Pre-permit (Operational) / Re-inspection            4526 46 st
# 7695     Pre-permit (Operational) / Initial Inspection        416 church ave
# 7696          Pre-permit (Operational) / Re-inspection        416 church ave
# 7697     Pre-permit (Operational) / Initial Inspection          512 court st
# 7698          Pre-permit (Operational) / Re-inspection          512 court st
# 7699     Pre-permit (Operational) / Initial Inspection          730 e 149 st
# 7700     Pre-permit (Operational) / Initial Inspection   4864 arthur kill rd
# 7701     Pre-permit (Operational) / Initial Inspection            8621 4 ave
# 7702          Pre-permit (Operational) / Re-inspection            8621 4 ave
# 7703     Pre-permit (Operational) / Initial Inspection    134 westchester sq
# 7704          Pre-permit (Operational) / Re-inspection    134 westchester sq
# 7705     Pre-permit (Operational) / Initial Inspection      17713 union tpke
# 7706     Pre-permit (Operational) / Initial Inspection           137 e 45 st
#
#       zip_code  rating price      cuisine
# 0        10462     4.0    $$     bakeries
# 1        10462     4.0    $$     bakeries
# 2        10462     4.0    $$     bakeries
# 3        11218     3.5     $     icecream
# 4        11218     3.5     $     icecream
# 5        11218     3.5     $     icecream
# 6        11356     4.5     $        delis
# 7        11356     4.5     $        delis
# 8        11356     4.5     $        delis
# 9        11356     4.5     $        delis
# 10       11356     4.5     $        delis
# 11       11356     4.5     $        delis
# 12       11356     4.5     $        delis
# 13       11356     4.5     $        delis
# 14       10005     2.0     $   sandwiches
# 15       10005     2.0     $   sandwiches
# 16       10005     2.0     $   sandwiches
# 17       10005     2.0     $   sandwiches
# 18       10005     2.0     $   sandwiches
# 19       10005     2.0     $   sandwiches
# 20       10005     2.0     $   sandwiches
# 21       10005     2.0     $   sandwiches
# 22       10005     2.0     $   sandwiches
# 23       10005     2.0     $   sandwiches
# 24       10005     2.0     $   sandwiches
# 25       11201     2.0     $       donuts
# 26       11201     1.0     $       donuts
# 27       11201     2.0     $       donuts
# 28       11201     1.0     $       donuts
# 29       11201     2.0     $       donuts
# ...        ...     ...   ...          ...
# 7677     10036     3.5    $$     japanese
# 7678     10036     3.5    $$     japanese
# 7679     10014     3.0     $      gaybars
# 7680     11225     5.0    $$    wine_bars
# 7681     11225     5.0    $$    wine_bars
# 7682     10069     2.0    $$      chinese
# 7683     10069     2.0    $$      chinese
# 7684     11369     3.5    $$       diners
# 7685     11249     4.0    $$         thai
# 7686     11249     4.0    $$         thai
# 7687     10302     3.0    $$      buffets
# 7688     10302     3.0    $$      buffets
# 7689     10302     3.0    $$      buffets
# 7690     10302     3.0    $$      buffets
# 7691     11234     3.5    $$       kosher
# 7692     11234     3.5    $$       kosher
# 7693     11104     3.5     $      chinese
# 7694     11104     3.5     $      chinese
# 7695     11218     4.5    $$         thai
# 7696     11218     4.5    $$         thai
# 7697     11231     3.5    $$     japanese
# 7698     11231     3.5    $$     japanese
# 7699     10455     2.0     $  restaurants
# 7700     10309     4.0    $$      italian
# 7701     11209     3.5     $      chinese
# 7702     11209     3.5     $      chinese
# 7703     10461     4.5     $        delis
# 7704     10461     4.5     $        delis
# 7705     11366     4.5    $$     japanese
# 7706     10017     2.0    $$        sushi
#
# [7707 rows x 20 columns]

# %%
len(df_combined.camis.unique())
# Out:
# 1388

# %% [markdown]
# ### Save the data as csv

# %%
df_combined.to_csv('../dataset/final.csv')
